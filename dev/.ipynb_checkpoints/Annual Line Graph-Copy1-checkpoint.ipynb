# %% [markdown]
# # <center> This is a Work in Progress!! </center>
#
# ## I am attempting going to split this into two line graphs:
#  ### 1) All incidents throughout the year
#  ### 2) Incidents per Category Through the year
#
# #### I am leaving off with reducing the tick marks for the first of the two plots mentioned above

# %%
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd

# %%
traffic_df = pd.read_csv('Resources/traffic (main).csv')
traffic_df.head()
# Out:
#    Unnamed: 0                         Address      Issue Reported   Latitude  \
# 0           0                  5400 Brodie Ln  Accident/Collision  30.230326
# 1           1            8800 Corran Ferry Dr  Accident/Collision  30.201610
# 2           2     N Lamar Blvd Nb & Morrow St  Accident/Collision  30.343978
# 3           3                11000 Fm 2222 Rd  Accident/Collision  30.396632
# 4           4  Mount Bonnell Rd & Tortuga Trl  Accident/Collision  30.339233
#
#                    Location  Longitude      Date Time Published  \
# 0  (30.2303264,-97.8199774) -97.819977  2017-09-26T11:11:00.000
# 1  (30.2016097,-97.8530411) -97.853041  2017-09-26T11:19:00.000
# 2  (30.3439776,-97.7149716) -97.714972  2017-09-26T11:55:00.000
# 3  (30.3966315,-97.8487281) -97.848728  2017-09-26T12:08:00.000
# 4   (30.339233,-97.7779837) -97.777984  2017-09-26T12:20:00.000
#
#                           Traffic Report ID Traffic Report Status (TRS)  \
# ...

# %%
#dates = traffic_df.Date
dategroup = traffic_df.groupby('Date').count()
incidentsperday = dategroup['Issue Reported']
incidentsperday[:10]
# Out:
# Date
# 2017-09-26     23
# 2017-09-27    119
# 2017-09-28    231
# 2017-09-29    195
# 2017-09-30    132
# 2017-10-01     66
# 2017-10-02    104
# 2017-10-03    146
# 2017-10-04     70
# 2017-10-05     64
# Name: Issue Reported, dtype: int64

# %%
'''
fig, ax = plt.subplots()
ax.plot(incidentsperday.index, incidentsperday)
ax.xaxis_date()     # interpret the x-axis values as dates
fig.autofmt_xdate() # make space for and rotate the x-axis tick labels
'''



annualdailyincidents = plt.plot(incidentsperday.index, incidentsperday)
plt.locator_params(axis='x', numticks=2)
plt.xticks(rotation=70)
plt.show()
#plt.xticks(incidentsperday, incidentsperday.index.values ) # location, labels
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# /Users/Omar/anaconda3/envs/pythonomy/lib/python3.6/site-packages/matplotlib/ticker.py:1437: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.category.StrCategoryLocator'>
#   str(type(self)))

# %%
plt.savefig('../Deliverables/Incidents Per Day Line Graph (Annual).png')

# %%
categroup = traffic_df.groupby('Issue Reported').count()
#incidentsperday = dategroup['Issue Reported']
#incidentsperday[:10]


categroup
# Out:
#                     Unnamed: 0  Address  Latitude  Location  Longitude  \
# Issue Reported
# Accident/Collision       40162    40162     40162     40162      40162
# Traffic Hazard           28661    28661     28661     28661      28661
# Traffic Impediment       11262    11262     11262     11262      11262
#
#                     Date Time Published  Traffic Report ID  \
# Issue Reported
# Accident/Collision                40162              40162
# Traffic Hazard                    28661              28661
# Traffic Impediment                11262              11262
#
#                     Traffic Report Status (TRS)  TRS Date Time   Date   Time
# Issue Reported
# Accident/Collision                        40162          40162  40162  40162
# Traffic Hazard                            28661          28661  28661  28661
# Traffic Impediment                        11262          11262  11262  11262

# %%
40162 + 28661 + 11262
# Out:
# 80085

# %%
categroup.Address
# Out:
# Issue Reported
# Accident/Collision    40162
# Traffic Hazard        28661
# Traffic Impediment    11262
# Name: Address, dtype: int64

# %%
traffic_df.head()
# Out:
#    Unnamed: 0                         Address      Issue Reported   Latitude  \
# 0           0                  5400 Brodie Ln  Accident/Collision  30.230326
# 1           1            8800 Corran Ferry Dr  Accident/Collision  30.201610
# 2           2     N Lamar Blvd Nb & Morrow St  Accident/Collision  30.343978
# 3           3                11000 Fm 2222 Rd  Accident/Collision  30.396632
# 4           4  Mount Bonnell Rd & Tortuga Trl  Accident/Collision  30.339233
#
#                    Location  Longitude      Date Time Published  \
# 0  (30.2303264,-97.8199774) -97.819977  2017-09-26T11:11:00.000
# 1  (30.2016097,-97.8530411) -97.853041  2017-09-26T11:19:00.000
# 2  (30.3439776,-97.7149716) -97.714972  2017-09-26T11:55:00.000
# 3  (30.3966315,-97.8487281) -97.848728  2017-09-26T12:08:00.000
# 4   (30.339233,-97.7779837) -97.777984  2017-09-26T12:20:00.000
#
#                           Traffic Report ID Traffic Report Status (TRS)  \
# ...

# %%
accident_df = traffic_df[traffic_df['Issue Reported'] == ('Accident/Collision')]
accident_df.head()
# Out:
#    Unnamed: 0                         Address      Issue Reported   Latitude  \
# 0           0                  5400 Brodie Ln  Accident/Collision  30.230326
# 1           1            8800 Corran Ferry Dr  Accident/Collision  30.201610
# 2           2     N Lamar Blvd Nb & Morrow St  Accident/Collision  30.343978
# 3           3                11000 Fm 2222 Rd  Accident/Collision  30.396632
# 4           4  Mount Bonnell Rd & Tortuga Trl  Accident/Collision  30.339233
#
#                    Location  Longitude      Date Time Published  \
# 0  (30.2303264,-97.8199774) -97.819977  2017-09-26T11:11:00.000
# 1  (30.2016097,-97.8530411) -97.853041  2017-09-26T11:19:00.000
# 2  (30.3439776,-97.7149716) -97.714972  2017-09-26T11:55:00.000
# 3  (30.3966315,-97.8487281) -97.848728  2017-09-26T12:08:00.000
# 4   (30.339233,-97.7779837) -97.777984  2017-09-26T12:20:00.000
#
#                           Traffic Report ID Traffic Report Status (TRS)  \
# ...

# %%
hazard_df = traffic_df[traffic_df['Issue Reported'] == ('Traffic Hazard')]
hazard_df.head()
# Out:
#     Unnamed: 0                                  Address  Issue Reported  \
# 13          13           4120-4138 Mc Kinney Falls Pkwy  Traffic Hazard
# 15          15            7709 E Ben White Blvd Svrd Eb  Traffic Hazard
# 16          16                    3501-3621 W Braker Ln  Traffic Hazard
# 19          19                          5800 S Ih 35 Sb  Traffic Hazard
# 20          20  Scotland Well Dr & Spicewood Springs Rd  Traffic Hazard
#
#      Latitude                  Location  Longitude      Date Time Published  \
# 13  30.193885  (30.1938846,-97.6963741) -97.696374  2017-09-26T12:57:00.000
# 15  30.218273  (30.2182734,-97.6899232) -97.689923  2017-09-26T13:04:00.000
# 16  30.394128  (30.3941283,-97.7295793) -97.729579  2017-09-26T13:07:00.000
# 19  30.196947  (30.1969472,-97.7655666) -97.765567  2017-09-26T13:18:00.000
# 20  30.422533   (30.422533,-97.7936209) -97.793621  2017-09-26T13:26:00.000
#
#                            Traffic Report ID Traffic Report Status (TRS)  \
# ...

# %%
impediment_df = traffic_df[traffic_df['Issue Reported'] == ('Traffic Impediment')]
impediment_df.head()
# Out:
#     Unnamed: 0                Address      Issue Reported   Latitude  \
# 14          14   1512-1599 ENFIELD RD  Traffic Impediment  30.282624
# 25          25       14709 Reynero Ln  Traffic Impediment  30.089396
# 44          44     2950-2969 Manor Rd  Traffic Impediment  30.286127
# 45          45     5006 WEST WIND TRL  Traffic Impediment  30.226257
# 46          46  5400-5419 VILLAGE TRL  Traffic Impediment  30.195017
#
#                     Location  Longitude      Date Time Published  \
# 14  (30.2826236,-97.7569728) -97.756973  2017-09-26T13:01:00.000
# 25  (30.0893956,-97.6437964) -97.643796  2017-09-27T05:46:00.000
# 44  (30.2861274,-97.7078113) -97.707811  2017-09-27T07:55:00.000
# 45  (30.2262567,-97.8044428) -97.804443  2017-09-27T08:01:00.000
# 46  (30.1950165,-97.7458686) -97.745869  2017-09-27T08:09:00.000
#
#                            Traffic Report ID Traffic Report Status (TRS)  \
# 14  604CEF8BCDA23730DF21FEDA765B26CD969AF88E                    ARCHIVED
# ...
