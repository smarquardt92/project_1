# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import datetime
from pandas.io.json import json_normalize

# %%
#Retrieve the data

start_date = datetime.date(year=2017, month=9, day=1)
end_date = datetime.date(year=2018, month=12, day=1)
period = datetime.timedelta(days=1)

data = []

date = start_date

while date < end_date:
    the_date = date.strftime('%Y-%m-%d')
    url = f"https://data.austintexas.gov/resource/r3af-2r8x.json?$$app_token=PueZjmFITn1jWUQCgPpRj0QkW&$where=published_date between \'{the_date}T00:00:00\' and \'{the_date}T23:59:59\'"
    response = requests.get(url).json()
    data += response
    date += period
    
data
# Out:
# [{'address': '5400 Brodie Ln',
#   'issue_reported': 'COLLISION',
#   'latitude': '30.2303264',
#   'location': '(30.2303264,-97.8199774)',
#   'longitude': '-97.8199774',
#   'published_date': '2017-09-26T11:11:00.000',
#   'traffic_report_id': 'EC10DB9185C9C58A004FA683DD21AFCD16CAD418',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '8800 Corran Ferry Dr',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2016097',
#   'location': '(30.2016097,-97.8530411)',
#   'longitude': '-97.8530411',
#   'published_date': '2017-09-26T11:19:00.000',
#   'traffic_report_id': 'B25B748A59D8B6B5B5AE3E9D985289E795C874ED',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Lamar Blvd Nb & Morrow St',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3439776',
#   'location': '(30.3439776,-97.7149716)',
#   'longitude': '-97.7149716',
#   'published_date': '2017-09-26T11:55:00.000',
#   'traffic_report_id': 'B17F4787F2799F2665E5F119FC2F47D569212C4C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '11000 Fm 2222 Rd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3966315',
#   'location': '(30.3966315,-97.8487281)',
#   'longitude': '-97.8487281',
#   'published_date': '2017-09-26T12:08:00.000',
#   'traffic_report_id': '15D1EE116284B85E5DE3E00564518367FE994DE7',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Mount Bonnell Rd & Tortuga Trl',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.339233',
#   'location': '(30.339233,-97.7779837)',
#   'longitude': '-97.7779837',
#   'published_date': '2017-09-26T12:20:00.000',
#   'traffic_report_id': '89CA91E6C9B28BDCFB629B12758F955D21072594',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'E Martin Luther King Jr Blvd & Springdale Rd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2858671',
#   'location': '(30.2858671,-97.6826356)',
#   'longitude': '-97.6826356',
#   'published_date': '2017-09-26T12:22:00.000',
#   'traffic_report_id': 'F6D046A7EEB1146F8B1E81ABA2DD61FB74655DB0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5900 E BEN WHITE BLVD SVRD EB',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2135507',
#   'location': '(30.2135507,-97.7177042)',
#   'longitude': '-97.7177042',
#   'published_date': '2017-09-26T12:22:00.000',
#   'traffic_report_id': '8CE2F7CDC27D512A28746DB1E8895650F9355602',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'E CESAR CHAVEZ ST & TILLERY ST',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2517111',
#   'location': '(30.2517111,-97.7087842)',
#   'longitude': '-97.7087842',
#   'published_date': '2017-09-26T12:23:00.000',
#   'traffic_report_id': '2C61422714BCB5935215ADF442A8F5B1D80FFC54',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9503 Manchaca Rd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.1769932',
#   'location': '(30.1769932,-97.8219439)',
#   'longitude': '-97.8219439',
#   'published_date': '2017-09-26T12:27:00.000',
#   'traffic_report_id': '6EF79C21DD35EA505E11D0C6673B8A2588FA650B',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Jollyville Rd & Argonne Forest Trl',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4303312',
#   'location': '(30.4303312,-97.7647364)',
#   'longitude': '-97.7647364',
#   'published_date': '2017-09-26T12:40:00.000',
#   'traffic_report_id': 'C5C15732584ED2820DB3720243A42CA22F624D80',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1115-1139 E DEAN KEETON ST',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2860453',
#   'location': '(30.2860453,-97.7241858)',
#   'longitude': '-97.7241858',
#   'published_date': '2017-09-26T12:41:00.000',
#   'traffic_report_id': 'A9E76F7F478C7BE32C80F3BB0B7CC06E002D25BB',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12129 N FM 620 RD',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4615214',
#   'location': '(30.4615214,-97.8179448)',
#   'longitude': '-97.8179448',
#   'published_date': '2017-09-26T12:47:00.000',
#   'traffic_report_id': '51DA62A4D7C1AFEF718CCC35F07551F2BB3879F2',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '209 W 14th St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2764571',
#   'location': '(30.2764571,-97.7417605)',
#   'longitude': '-97.7417605',
#   'published_date': '2017-09-26T12:48:00.000',
#   'traffic_report_id': '055550DAD2FD7BB5AEE434F17CA74CA072982AC1',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '4120-4138 Mc Kinney Falls Pkwy',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1938846',
#   'location': '(30.1938846,-97.6963741)',
#   'longitude': '-97.6963741',
#   'published_date': '2017-09-26T12:57:00.000',
#   'traffic_report_id': '40B4EFAAA821A3B5B1282B8C60E1B82C3B05BAAE',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1512-1599 ENFIELD RD',
#   'issue_reported': 'zSTALLED VEHICLE',
#   'latitude': '30.2826236',
#   'location': '(30.2826236,-97.7569728)',
#   'longitude': '-97.7569728',
#   'published_date': '2017-09-26T13:01:00.000',
#   'traffic_report_id': '604CEF8BCDA23730DF21FEDA765B26CD969AF88E',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '7709 E Ben White Blvd Svrd Eb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2182734',
#   'location': '(30.2182734,-97.6899232)',
#   'longitude': '-97.6899232',
#   'published_date': '2017-09-26T13:04:00.000',
#   'traffic_report_id': '23B36EA4F70670AE377A591FDC03D36A9BEBB481',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3501-3621 W Braker Ln',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3941283',
#   'location': '(30.3941283,-97.7295793)',
#   'longitude': '-97.7295793',
#   'published_date': '2017-09-26T13:07:00.000',
#   'traffic_report_id': 'F3341DBCDDA605B1601524B0D01655750CC60E0D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '6808-7013 N Fm 620 Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4013341',
#   'location': '(30.4013341,-97.8553496)',
#   'longitude': '-97.8553496',
#   'published_date': '2017-09-26T13:08:00.000',
#   'traffic_report_id': '8F723119A7842320B2BC984B04D2A76808E8EBD7',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Fm 620 Rd & Comanche Trl',
#   'issue_reported': 'COLLISION WITH INJURY',
#   'latitude': '30.3943497',
#   'location': '(30.3943497,-97.8691306)',
#   'longitude': '-97.8691306',
#   'published_date': '2017-09-26T13:12:00.000',
#   'traffic_report_id': '00DC35710D10349FA58F9D679882587A0D70C16A',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5800 S Ih 35 Sb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1969472',
#   'location': '(30.1969472,-97.7655666)',
#   'longitude': '-97.7655666',
#   'published_date': '2017-09-26T13:18:00.000',
#   'traffic_report_id': '0CCC9BC1BB63CCC1F2123272DEF4A1963C2B60E5',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1500-BLK GRAND AVENUE PKWY',
#   'issue_reported': 'COLLISION',
#   'published_date': '2017-09-26T13:19:00.000',
#   'traffic_report_id': 'BBC42BB2D3F982AE8245231CA7EC8135A902BEFC',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Scotland Well Dr & Spicewood Springs Rd',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.422533',
#   'location': '(30.422533,-97.7936209)',
#   'longitude': '-97.7936209',
#   'published_date': '2017-09-26T13:26:00.000',
#   'traffic_report_id': '0311E1791C1FE92ECD3215FA0472BCE6BF2B252D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '14100 Mc Neil Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.4539975',
#   'location': '(30.4539975,-97.723598)',
#   'longitude': '-97.723598',
#   'published_date': '2017-09-26T13:30:00.000',
#   'traffic_report_id': '188602E741C1AD458EB69E6AC2B6DED0F4486404',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '0 S Cap Tx To Mopac Nb Ramp',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2508912',
#   'location': '(30.2508912,-97.8025573)',
#   'longitude': '-97.8025573',
#   'published_date': '2017-09-26T13:33:00.000',
#   'traffic_report_id': '6AFB24DE207D2E6952BA43F0E5B20BCDF0596CE5',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1701 E PARMER LN',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3868773',
#   'location': '(30.3868773,-97.6485355)',
#   'longitude': '-97.6485355',
#   'published_date': '2017-09-27T04:05:00.000',
#   'traffic_report_id': 'DD84F0EE24CFD17BA4AC744AFAD8DE1687C2A400',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5700 W US 290 HWY SVRD WB',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2366292',
#   'location': '(30.2366292,-97.8466029)',
#   'longitude': '-97.8466029',
#   'published_date': '2017-09-27T05:37:00.000',
#   'traffic_report_id': '4E90091068533B241B2634A3599D34ABCA4C11AF',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '14709 Reynero Ln',
#   'issue_reported': 'LOOSE LIVESTOCK',
#   'latitude': '30.0893956',
#   'location': '(30.0893956,-97.6437964)',
#   'longitude': '-97.6437964',
#   'published_date': '2017-09-27T05:46:00.000',
#   'traffic_report_id': '037C3EE7299BCED693B20196F1025EAEE60503AD',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1400 E ANDERSON LN SVRD WB',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3346821',
#   'location': '(30.3346821,-97.6900474)',
#   'longitude': '-97.6900474',
#   'published_date': '2017-09-27T06:04:00.000',
#   'traffic_report_id': '270EBCCA3BA16D800F173FE553E41E1A282156AB',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1190 Airport Blvd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2761878',
#   'location': '(30.2761878,-97.6998319)',
#   'longitude': '-97.6998319',
#   'published_date': '2017-09-27T06:06:00.000',
#   'traffic_report_id': 'A2E937136E57163ED6E6A73EB864E4F3F613EA67',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13900 N Ih 35 Sb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4278134',
#   'location': '(30.4278134,-97.6712764)',
#   'longitude': '-97.6712764',
#   'published_date': '2017-09-27T06:09:00.000',
#   'traffic_report_id': '77F30DE29B37C940918F2ABDD2D48CFFF2F092F0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5011 BURNET RD',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3217558',
#   'location': '(30.3217558,-97.7392649)',
#   'longitude': '-97.7392649',
#   'published_date': '2017-09-27T06:32:00.000',
#   'traffic_report_id': 'A7A134063601B2EC0851E7C2501B3F12D9EE2DE0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13985-14075 N US 183 HWY SVRD NB',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4734278',
#   'location': '(30.4734278,-97.798294)',
#   'longitude': '-97.798294',
#   'published_date': '2017-09-27T06:37:00.000',
#   'traffic_report_id': '0864A91883AB86909614F36A588EE81376A25C45',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9200-10215 S Mopac Expy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2006795',
#   'location': '(30.2006795,-97.8670959)',
#   'longitude': '-97.8670959',
#   'published_date': '2017-09-27T06:45:00.000',
#   'traffic_report_id': 'A7095041184FCA321A7B69AFA0B28972142BC486',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '822 Kramer Ln',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3798666',
#   'location': '(30.3798666,-97.6882209)',
#   'longitude': '-97.6882209',
#   'published_date': '2017-09-27T06:52:00.000',
#   'traffic_report_id': '954766448011A573ED48E3E92F4B069F62EF4B92',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13900 N Us 183 Hwy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4691798',
#   'location': '(30.4691798,-97.7975297)',
#   'longitude': '-97.7975297',
#   'published_date': '2017-09-27T06:53:00.000',
#   'traffic_report_id': 'CE7DD1F443C6AE6EBF3D40034D6EFF3F01AEF47C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12751-12845 N Us 183 Hwy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4337409',
#   'location': '(30.4337409,-97.7681098)',
#   'longitude': '-97.7681098',
#   'published_date': '2017-09-27T06:54:00.000',
#   'traffic_report_id': 'FEC3F49EB8E803BC30A24ED51FD04E89853CA09F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12847-13435 N Us 183 Hwy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4353815',
#   'location': '(30.4353815,-97.771437)',
#   'longitude': '-97.771437',
#   'published_date': '2017-09-27T06:54:00.000',
#   'traffic_report_id': 'D724888FAC8EBAAFB4E29572CC8A420C3726FB34',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13400 N Us 183 Hwy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4460408',
#   'location': '(30.4460408,-97.7893127)',
#   'longitude': '-97.7893127',
#   'published_date': '2017-09-27T06:54:00.000',
#   'traffic_report_id': 'A50274B028DF2DC7F5A78067724B2B8F7312F9B4',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '4600 S Ih 35 Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.209793',
#   'location': '(30.209793,-97.7560635)',
#   'longitude': '-97.7560635',
#   'published_date': '2017-09-27T07:10:00.000',
#   'traffic_report_id': '4A6C39763AD109EB75CE31C1EBFD53A0E883EE68',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Old Manchaca Rd & Riddle Rd',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1731638',
#   'location': '(30.1731638,-97.8306735)',
#   'longitude': '-97.8306735',
#   'published_date': '2017-09-27T07:13:00.000',
#   'traffic_report_id': 'FD85A4EE56F46CD4D324CE6951E61570FEB53012',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Lavaca St & W 8th St',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2705801',
#   'location': '(30.2705801,-97.7444959)',
#   'longitude': '-97.7444959',
#   'published_date': '2017-09-27T07:20:00.000',
#   'traffic_report_id': '5C82821CE203B916B7D33378F9E30009649E9E90',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Scofield Ridge Pkwy & N Mopac Expy Svrd Sb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4308203',
#   'location': '(30.4308203,-97.7012245)',
#   'longitude': '-97.7012245',
#   'published_date': '2017-09-27T07:22:00.000',
#   'traffic_report_id': '29EA1EE6C8971D4AE9C0516A4CD4D561801E0861',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5852-5863 E Martin Luther King Jr Blvd',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2857894',
#   'location': '(30.2857894,-97.6659299)',
#   'longitude': '-97.6659299',
#   'published_date': '2017-09-27T07:43:00.000',
#   'traffic_report_id': '8974B8371B6EF83D5E4699EA78BE68BE596453FE',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2800 Brinwood Ave',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2353583',
#   'location': '(30.2353583,-97.7600693)',
#   'longitude': '-97.7600693',
#   'published_date': '2017-09-27T07:46:00.000',
#   'traffic_report_id': 'F3B9B5274F80FDD4B64241FA92292E41EDABBE36',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '911 Westlake Dr',
#   'issue_reported': 'COLLISN/ LVNG SCN',
#   'latitude': '30.2920427',
#   'location': '(30.2920427,-97.7987843)',
#   'longitude': '-97.7987843',
#   'published_date': '2017-09-27T07:51:00.000',
#   'traffic_report_id': '15E3D8B8D931C5F180D0AFDC51D9E661F172A299',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2950-2969 Manor Rd',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2861274',
#   'location': '(30.2861274,-97.7078113)',
#   'longitude': '-97.7078113',
#   'published_date': '2017-09-27T07:55:00.000',
#   'traffic_report_id': '4EC43D88785FFFDCBE0AA3DD739F11CDD2A8C302',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5006 WEST WIND TRL',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2262567',
#   'location': '(30.2262567,-97.8044428)',
#   'longitude': '-97.8044428',
#   'published_date': '2017-09-27T08:01:00.000',
#   'traffic_report_id': '683EE255F1CA66BE11148819896F8F560E126539',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5400-5419 VILLAGE TRL',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.1950165',
#   'location': '(30.1950165,-97.7458686)',
#   'longitude': '-97.7458686',
#   'published_date': '2017-09-27T08:09:00.000',
#   'traffic_report_id': 'F5F021C67E90384CA25475CBB107B5EC7CFDB055',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5100-5198 W WILLIAM CANNON DR',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2249534',
#   'location': '(30.2249534,-97.8493318)',
#   'longitude': '-97.8493318',
#   'published_date': '2017-09-27T08:09:00.000',
#   'traffic_report_id': 'D57E26B7373EC13D398C5F457CE8783839950FE0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1700 W Parmer Ln',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4129054',
#   'location': '(30.4129054,-97.6896148)',
#   'longitude': '-97.6896148',
#   'published_date': '2017-09-27T08:31:00.000',
#   'traffic_report_id': '48D317A055F42F511B580CB8D17221BFA0E3DB1C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Connie St & Three Points Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.4540729',
#   'location': '(30.4540729,-97.6669692)',
#   'longitude': '-97.6669692',
#   'published_date': '2017-09-27T08:34:00.000',
#   'traffic_report_id': '04085CEF4A2F22B0D7DE2D6919476571400985C3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9511 Aberdeen Way',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3547925',
#   'location': '(30.3547925,-97.6774407)',
#   'longitude': '-97.6774407',
#   'published_date': '2017-09-27T08:48:00.000',
#   'traffic_report_id': '8710BCA93219049B5D36136FD05D626A930BD773',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '0 S Ih 35 Nb To Onion Creek Ramp',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1296361',
#   'location': '(30.1296361,-97.7999654)',
#   'longitude': '-97.7999654',
#   'published_date': '2017-09-27T08:56:00.000',
#   'traffic_report_id': '5B48D88A19941E3F151D49ECD72B30B650EA917A',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5100 N Ih 35 Sb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3101942',
#   'location': '(30.3101942,-97.7113741)',
#   'longitude': '-97.7113741',
#   'published_date': '2017-09-27T08:59:00.000',
#   'traffic_report_id': '095719A3FF80CB6C8AC4E0E7B8E7DA0881234A18',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9308 S 1st St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.1700928',
#   'location': '(30.1700928,-97.8014855)',
#   'longitude': '-97.8014855',
#   'published_date': '2017-09-27T09:19:00.000',
#   'traffic_report_id': '46FE210FB683DF0AF5B7191B2EB29621D82F5266',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1010 W Rundberg Ln',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.364966',
#   'location': '(30.364966,-97.7008661)',
#   'longitude': '-97.7008661',
#   'published_date': '2017-09-27T09:24:00.000',
#   'traffic_report_id': 'D9BC87DD9580C87C7378651D4235E297EBB962ED',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1403 Newfield Ln',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2843137',
#   'location': '(30.2843137,-97.7638358)',
#   'longitude': '-97.7638358',
#   'published_date': '2017-09-27T09:24:00.000',
#   'traffic_report_id': '40CB0A6EC9C6368854FB0EE4942DC54A38F57D78',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '500 E 7th St',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2677487',
#   'location': '(30.2677487,-97.7378736)',
#   'longitude': '-97.7378736',
#   'published_date': '2017-09-27T09:28:00.000',
#   'traffic_report_id': '0C6C6202E87A7DF9FC1CF44B4ADE2F311CB5AC62',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'E Dean Keeton St & Red River St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2871718',
#   'location': '(30.2871718,-97.7267502)',
#   'longitude': '-97.7267502',
#   'published_date': '2017-09-27T09:35:00.000',
#   'traffic_report_id': '18C103DF09F1053DC5221AA29DC2D0FE8B19ED6D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5996-5997 Bee Caves Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.2955854',
#   'location': '(30.2955854,-97.8275047)',
#   'longitude': '-97.8275047',
#   'published_date': '2017-09-27T09:37:00.000',
#   'traffic_report_id': 'F2AB78F5097F975794065615DC6F9DA887CDA3C0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1-901 S Ih 35 Nb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2507403',
#   'location': '(30.2507403,-97.7357903)',
#   'longitude': '-97.7357903',
#   'published_date': '2017-09-27T09:42:00.000',
#   'traffic_report_id': 'EE8593B3AF2B2A4FB2CA630BCE6BE677E6585F5C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1599 W Wells Branch Pkwy',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4400814',
#   'location': '(30.4400814,-97.6694473)',
#   'longitude': '-97.6694473',
#   'published_date': '2017-09-27T09:43:00.000',
#   'traffic_report_id': 'C1CDACA40793908F4DA39B235D3016D1202E1CB3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1500 S Ih 35 Sb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2423845',
#   'location': '(30.2423845,-97.7362061)',
#   'longitude': '-97.7362061',
#   'published_date': '2017-09-27T09:43:00.000',
#   'traffic_report_id': '50DAC89F6D32513B42B26CBB102EBF039700C2E3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1434 W Wells Branch Pkwy',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4413424',
#   'location': '(30.4413424,-97.6649838)',
#   'longitude': '-97.6649838',
#   'published_date': '2017-09-27T09:45:00.000',
#   'traffic_report_id': 'DC146B6E14AE3DBB606428DD279DD15EF31E3E66',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '508 E Howard Ln',
#   'issue_reported': 'COLLISION/PRIVATE PROPERTY',
#   'latitude': '30.4142661',
#   'location': '(30.4142661,-97.6543495)',
#   'longitude': '-97.6543495',
#   'published_date': '2017-09-27T09:50:00.000',
#   'traffic_report_id': 'C61211674FD03175FEC87A9C01F39F72376CE104',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3300-3649 N Mopac Expy Nb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2489266',
#   'location': '(30.2489266,-97.8065469)',
#   'longitude': '-97.8065469',
#   'published_date': '2017-09-27T09:52:00.000',
#   'traffic_report_id': '7ABCEEFDCAA05A571408540BD4862CD2F3AAD7A5',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '15119 N Ih 35 Svrd Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.444013',
#   'location': '(30.444013,-97.6673279)',
#   'longitude': '-97.6673279',
#   'published_date': '2017-09-27T09:57:00.000',
#   'traffic_report_id': '899A19B6BEC5CDDC50179F183BA138B628CF94B3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '701 S Capital Of Texas Hwy Nb',
#   'issue_reported': 'COLLISION/PRIVATE PROPERTY',
#   'latitude': '30.2929308',
#   'location': '(30.2929308,-97.8280935)',
#   'longitude': '-97.8280935',
#   'published_date': '2017-09-27T10:14:00.000',
#   'traffic_report_id': '8D62C4400092573EFA143A5159280E6A68AF5274',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'W Braker Ln & Burnet Rd',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3911708',
#   'location': '(30.3911708,-97.7218162)',
#   'longitude': '-97.7218162',
#   'published_date': '2017-09-27T10:34:00.000',
#   'traffic_report_id': '9587915E367335B4E286DBC435585857DB78C0C5',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Old Manchaca Rd & Riddle Rd',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.1731638',
#   'location': '(30.1731638,-97.8306735)',
#   'longitude': '-97.8306735',
#   'published_date': '2017-09-27T10:48:00.000',
#   'traffic_report_id': '09203A0B810D0C054F3F15D6DB42AA850BEA9174',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1934-1950 W William Cannon Dr',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2027469',
#   'location': '(30.2027469,-97.8055244)',
#   'longitude': '-97.8055244',
#   'published_date': '2017-09-27T10:50:00.000',
#   'traffic_report_id': '07F97CC68EEBF81AFCD32F6FC0AAD7E1F17E0C00',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9200-9507 Bluff Springs Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.1572743',
#   'location': '(30.1572743,-97.7692511)',
#   'longitude': '-97.7692511',
#   'published_date': '2017-09-27T10:59:00.000',
#   'traffic_report_id': '6B6D41EB529DB021F57A81B33FDFD65D296485DA',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '10211-11149 Research Blvd Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3950279',
#   'location': '(30.3950279,-97.7461912)',
#   'longitude': '-97.7461912',
#   'published_date': '2017-09-27T11:07:00.000',
#   'traffic_report_id': '2F70E239C7A5D80384275BE451075E4CB7125E9E',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Manor Rd & N Ih 35 Svrd Nb',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2829904',
#   'location': '(30.2829904,-97.7269282)',
#   'longitude': '-97.7269282',
#   'published_date': '2017-09-27T11:17:00.000',
#   'traffic_report_id': '5BBD5046C9B461CA6F1549F3F39C240A9C5702F9',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '11300 S Ih 35 Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1376429',
#   'location': '(30.1376429,-97.797498)',
#   'longitude': '-97.797498',
#   'published_date': '2017-09-27T11:17:00.000',
#   'traffic_report_id': '2E5A616A2CB3B91852EAFE6C9F29C186CC2EFD2E',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '6900 S Ih 35 Sb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.1865285',
#   'location': '(30.1865285,-97.7734949)',
#   'longitude': '-97.7734949',
#   'published_date': '2017-09-27T11:24:00.000',
#   'traffic_report_id': '4B3DD95E69E77EFEAA3844FD6F6F6FFC5C3BD3F1',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'W Huntland Dr & Airport Blvd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3303848',
#   'location': '(30.3303848,-97.7156439)',
#   'longitude': '-97.7156439',
#   'published_date': '2017-09-27T11:32:00.000',
#   'traffic_report_id': '4B19229E380E9CA29673FDB967FD09CDCF4B5B44',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'S 1st St & W Stassney Ln',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2084771',
#   'location': '(30.2084771,-97.7815312)',
#   'longitude': '-97.7815312',
#   'published_date': '2017-09-27T11:37:00.000',
#   'traffic_report_id': 'E9A20A4AF61C91B0232679BC583058B278FB2926',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '100-398 TWIN CREEKS RD',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.1254657',
#   'location': '(30.1254657,-97.8198303)',
#   'longitude': '-97.8198303',
#   'published_date': '2017-09-27T11:42:00.000',
#   'traffic_report_id': 'E6058169CBE1692B9BF9E73BE49D2B873BEA58CB',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Ih 35 Svrd Sb & E 30th St',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2879324',
#   'location': '(30.2879324,-97.7243055)',
#   'longitude': '-97.7243055',
#   'published_date': '2017-09-27T11:44:00.000',
#   'traffic_report_id': '736CCA45634B541786A2049311BC717ECBD88D60',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3960 WESTLAKE DR',
#   'issue_reported': 'COLLISION',
#   'latitude': '30.3282562',
#   'location': '(30.3282562,-97.7842077)',
#   'longitude': '-97.7842077',
#   'published_date': '2017-09-27T11:44:00.000',
#   'traffic_report_id': '112B7848FC02DAFC29E7553C50061468A534AC98',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12500-12579 Research Blvd Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.428624',
#   'location': '(30.428624,-97.7586454)',
#   'longitude': '-97.7586454',
#   'published_date': '2017-09-27T11:45:00.000',
#   'traffic_report_id': '4A4AB45448022F0C738FE9E310148EA1EB7F856B',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '7526-8022 E Us 290 Hwy Wb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3252674',
#   'location': '(30.3252674,-97.6748287)',
#   'longitude': '-97.6748287',
#   'published_date': '2017-09-27T11:46:00.000',
#   'traffic_report_id': 'DC5A02AD7C6CC4B77E93DC175800619E7E684464',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '8613-9115 E Us 290 Hwy Eb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3280966',
#   'location': '(30.3280966,-97.6593543)',
#   'longitude': '-97.6593543',
#   'published_date': '2017-09-27T11:48:00.000',
#   'traffic_report_id': 'E41C8FD8D6DA74A91FC96008280BAEA77725B5A7',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '7400 N Ih 35 Nb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3354614',
#   'location': '(30.3354614,-97.7030777)',
#   'longitude': '-97.7030777',
#   'published_date': '2017-09-27T11:49:00.000',
#   'traffic_report_id': 'A739EB585292BE58C99962FD287ACAFB1A459B72',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'W Parmer Ln & Tomanet Trl',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4183342',
#   'location': '(30.4183342,-97.7008928)',
#   'longitude': '-97.7008928',
#   'published_date': '2017-09-27T12:00:00.000',
#   'traffic_report_id': '906063F00D2555893E5C32E9249AE185AE689A7B',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '8601 Tuscany Way',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3335505',
#   'location': '(30.3335505,-97.6583511)',
#   'longitude': '-97.6583511',
#   'published_date': '2017-09-27T12:02:00.000',
#   'traffic_report_id': '83EC73D69436A58D7BD6BA448A17C1AA22D950C8',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3150-3219 S Fm 973 Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2042907',
#   'location': '(30.2042907,-97.6390458)',
#   'longitude': '-97.6390458',
#   'published_date': '2017-09-27T12:07:00.000',
#   'traffic_report_id': 'B74E9CAD775D997FC742B45E1BA7BD5295D63D13',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1200-1433 E Anderson Ln Svrd Eb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.335523',
#   'location': '(30.335523,-97.6918631)',
#   'longitude': '-97.6918631',
#   'published_date': '2017-09-27T12:08:00.000',
#   'traffic_report_id': '8334918DA76533B5C14F235F374E327C95035AA3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13812-13822 N Ih 35 Svrd Sb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.1021832',
#   'location': '(30.1021832,-97.8123125)',
#   'longitude': '-97.8123125',
#   'published_date': '2017-09-27T12:22:00.000',
#   'traffic_report_id': '297BEB01DD21C5A2AAD009DA6ABB91D4BC0FDC6D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Sh 130 Svrd Sb & Fm 969 Rd',
#   'issue_reported': 'COLLISION/PRIVATE PROPERTY',
#   'latitude': '30.2540255',
#   'location': '(30.2540255,-97.6050244)',
#   'longitude': '-97.6050244',
#   'published_date': '2017-09-27T12:30:00.000',
#   'traffic_report_id': 'F9645347D5B2C4DB96EDB49A55AD3B9451CA9F6E',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5900 Manor Rd',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3065452',
#   'location': '(30.3065452,-97.6800816)',
#   'longitude': '-97.6800816',
#   'published_date': '2017-09-27T12:30:00.000',
#   'traffic_report_id': '229BE39E04F960E46D8A64CADC8B4534E6BFC364',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3105 S Ih 35 Svrd Nb',
#   'issue_reported': 'COLLISION',
#   'latitude': '30.2255369',
#   'location': '(30.2255369,-97.7455368)',
#   'longitude': '-97.7455368',
#   'published_date': '2017-09-27T12:37:00.000',
#   'traffic_report_id': '59976704CF42F25B77F2108792C193383EAEAC10',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Neenah Ave & W Parmer Ln',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4879587',
#   'location': '(30.4879587,-97.7713383)',
#   'longitude': '-97.7713383',
#   'published_date': '2017-09-27T12:49:00.000',
#   'traffic_report_id': '7340CA224C5C8D2B89562159A4D81D9225A20E65',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Guadalupe St & W 5th St',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2680986',
#   'location': '(30.2680986,-97.746641)',
#   'longitude': '-97.746641',
#   'published_date': '2017-09-27T13:12:00.000',
#   'traffic_report_id': '64C84E952453CD25D3097C7CFB8BA8178A0D109F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '10013-10015 E Us 290 Hwy Svrd Eb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3396198',
#   'location': '(30.3396198,-97.5918402)',
#   'longitude': '-97.5918402',
#   'published_date': '2017-09-27T13:22:00.000',
#   'traffic_report_id': '9147343D9851D9A4727FAB30D6594B416109E55A',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9300 RESEARCH BLVD NB',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3810412',
#   'location': '(30.3810412,-97.7404868)',
#   'longitude': '-97.7404868',
#   'published_date': '2017-09-27T13:24:00.000',
#   'traffic_report_id': 'A3625F643C5DFB9C0CEE12E29C57FE264FBD4FEF',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9210 Northgate Blvd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3718766',
#   'location': '(30.3718766,-97.7157452)',
#   'longitude': '-97.7157452',
#   'published_date': '2017-09-27T13:29:00.000',
#   'traffic_report_id': '619683DB9EF9D4649743EE1DEDDB3923D6E5F704',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12100-12131 N Fm 973 Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.3353742',
#   'location': '(30.3353742,-97.559151)',
#   'longitude': '-97.559151',
#   'published_date': '2017-09-27T13:37:00.000',
#   'traffic_report_id': '8F102B2BE79803391E93A93E7B21A98FEE3F781A',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'E Parmer Ln & Dessau Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3870092',
#   'location': '(30.3870092,-97.6485476)',
#   'longitude': '-97.6485476',
#   'published_date': '2017-09-27T13:52:00.000',
#   'traffic_report_id': 'B01F67ADB17354737D273B0CAE8D36366B08AF91',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '400-blk Lohmans Ford Rd',
#   'issue_reported': 'COLLISION',
#   'published_date': '2017-09-27T13:57:00.000',
#   'traffic_report_id': 'C1D262A03495880AB003DDE6D06A10E9E84013F5',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1143 Airport Blvd',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2715751',
#   'location': '(30.2715751,-97.6972527)',
#   'longitude': '-97.6972527',
#   'published_date': '2017-09-27T14:02:00.000',
#   'traffic_report_id': 'C18557DED94F94DC63CBCEC520F2FEEB823C4E3D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5725 E Parmer Ln',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3684961',
#   'location': '(30.3684961,-97.6139029)',
#   'longitude': '-97.6139029',
#   'published_date': '2017-09-27T14:05:00.000',
#   'traffic_report_id': 'FD5A768E47CA87449299D0544F4325C4E2B34388',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3107 Hemphill Park',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2969248',
#   'location': '(30.2969248,-97.7388776)',
#   'longitude': '-97.7388776',
#   'published_date': '2017-09-27T14:24:00.000',
#   'traffic_report_id': '6F34A3E0E1AF181E8A78E70C146682B7EAD12846',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '4700 S Ih 35 Sb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2085001',
#   'location': '(30.2085001,-97.7568594)',
#   'longitude': '-97.7568594',
#   'published_date': '2017-09-27T14:31:00.000',
#   'traffic_report_id': '62634625ADA7C706B0BE053ED4469260300D5658',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '800-898 S Mopac Expy Svrd Sb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2671996',
#   'location': '(30.2671996,-97.7808755)',
#   'longitude': '-97.7808755',
#   'published_date': '2017-09-27T14:31:00.000',
#   'traffic_report_id': '0D87FBCB22B5F8B076A822CE143E0D0BE02892D9',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2300-2530 E Ben White Blvd Wb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2324233',
#   'location': '(30.2324233,-97.792895)',
#   'longitude': '-97.792895',
#   'published_date': '2017-09-27T14:40:00.000',
#   'traffic_report_id': '5427674F55437297C338DEADBB57EC839B5A6DDD',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Fm 620 Rd & Mansfield Dam Rd',
#   'issue_reported': 'TRFC HAZD/ DEBRIS',
#   'latitude': '30.3954573',
#   'location': '(30.3954573,-97.9139274)',
#   'longitude': '-97.9139274',
#   'published_date': '2017-09-27T14:42:00.000',
#   'traffic_report_id': 'EAE18E90C55AFEFAE7F95DF6164CF084AC2FBC54',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '4346-4364 N Fm 620 Rd',
#   'issue_reported': 'COLLISION WITH INJURY',
#   'latitude': '30.3901772',
#   'location': '(30.3901772,-97.9088721)',
#   'longitude': '-97.9088721',
#   'published_date': '2017-09-27T14:45:00.000',
#   'traffic_report_id': 'EEEA8C6D5510BE2A8FC4D34A4E6C0D7BB69407F9',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '200-344 E Ben White Blvd Wb',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2239607',
#   'location': '(30.2239607,-97.7651973)',
#   'longitude': '-97.7651973',
#   'published_date': '2017-09-27T15:03:00.000',
#   'traffic_report_id': '49820F6FD5C388C563F6BEAEF5585A2AD3DC8413',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5701 W Slaughter Ln',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2009076',
#   'location': '(30.2009076,-97.8669715)',
#   'longitude': '-97.8669715',
#   'published_date': '2017-09-27T15:34:00.000',
#   'traffic_report_id': '0E55C1A2D589C70E5CFE4C2ECDB1CCD2607AA44F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '4400-4708 E Ben White Blvd Wb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.215463',
#   'location': '(30.215463,-97.7349646)',
#   'longitude': '-97.7349646',
#   'published_date': '2017-09-27T15:59:00.000',
#   'traffic_report_id': '00B4A051351B585E1F29FFCE2B7FF5D29D629966',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '200-344 E Ben White Blvd Wb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2239607',
#   'location': '(30.2239607,-97.7651973)',
#   'longitude': '-97.7651973',
#   'published_date': '2017-09-27T16:16:00.000',
#   'traffic_report_id': 'A0E3EAB3C80118379CB2E1D7B163F82494430E03',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '10633 E US 290 HWY EB',
#   'issue_reported': 'COLLISION',
#   'latitude': '30.3476742',
#   'location': '(30.3476742,-97.5637421)',
#   'longitude': '-97.5637421',
#   'published_date': '2017-09-27T16:34:00.000',
#   'traffic_report_id': '7DFF5635BAC02F55BBF2B802C7C72FBB229B548B',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1100 Guadalupe St',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2737642',
#   'location': '(30.2737642,-97.7446356)',
#   'longitude': '-97.7446356',
#   'published_date': '2017-09-27T16:40:00.000',
#   'traffic_report_id': '348E495881EF4526FE8E38DBA4CEAA49B829B8B2',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Cameron Rd & E Anderson Ln Svrd Wb',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3328441',
#   'location': '(30.3328441,-97.6861768)',
#   'longitude': '-97.6861768',
#   'published_date': '2017-09-27T16:51:00.000',
#   'traffic_report_id': 'EAD98E0E365D07598A35BA682210564193928571',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '11900-11925 S Mopac Expy Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4083404',
#   'location': '(30.4083404,-97.7180555)',
#   'longitude': '-97.7180555',
#   'published_date': '2017-09-27T16:54:00.000',
#   'traffic_report_id': '23BFD8A26FDEAA0CCF8A0B3F8705506064A99BA0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '14600-15013 N Mopac Expy Nb',
#   'issue_reported': 'COLLISION',
#   'latitude': '30.4498798',
#   'location': '(30.4498798,-97.6965368)',
#   'longitude': '-97.6965368',
#   'published_date': '2017-09-27T16:58:00.000',
#   'traffic_report_id': 'C577B1BDB8564E08B301695D6D6FC4DFE4BBFB77',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '8516 Shallot Way',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.1746656',
#   'location': '(30.1746656,-97.789001)',
#   'longitude': '-97.789001',
#   'published_date': '2017-09-27T16:58:00.000',
#   'traffic_report_id': '4144A50012A273C9A22B8E634D0EF46FA90835E4',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '15015-15233 N Mopac Expy Nb',
#   'issue_reported': 'COLLISION WITH INJURY',
#   'latitude': '30.4576294',
#   'location': '(30.4576294,-97.6979427)',
#   'longitude': '-97.6979427',
#   'published_date': '2017-09-27T17:00:00.000',
#   'traffic_report_id': '941B11D1510AA9D549D5CBC8C521572BEBC8337A',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '12300 N IH 35 NB',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4012165',
#   'location': '(30.4012165,-97.6745641)',
#   'longitude': '-97.6745641',
#   'published_date': '2017-09-27T17:11:00.000',
#   'traffic_report_id': '85D0662AD5825BA33F4259D0D06AC035ABAC67BF',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '14500 N Ih 35 Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.4363953',
#   'location': '(30.4363953,-97.6697394)',
#   'longitude': '-97.6697394',
#   'published_date': '2017-09-27T17:16:00.000',
#   'traffic_report_id': 'CBF641003962D3B22EA5AEB9164C4CFF46A13515',
# ...
#   'traffic_report_id': '7203E9C4F56B0AAE54410BC7420428C990516A31',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'E 15th St & San Jacinto Blvd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2762365',
#   'location': '(30.2762365,-97.7371166)',
#   'longitude': '-97.7371166',
#   'published_date': '2017-10-03T08:09:00.000',
#   'traffic_report_id': 'D91149F7FF51BE92003E0BDA07CFD0FC2B514AFF',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1310-1319 W 24TH ST',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2885158',
#   'location': '(30.2885158,-97.7516354)',
#   'longitude': '-97.7516354',
#   'published_date': '2017-10-03T08:14:00.000',
#   'traffic_report_id': '05A5BB2081A861C7BAC6E2F3980CB63D644E17B3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13729 N Us 183 Hwy Svrd Nb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4586141',
#   'location': '(30.4586141,-97.7923618)',
#   'longitude': '-97.7923618',
#   'published_date': '2017-10-03T08:21:00.000',
#   'traffic_report_id': 'F4135B99ABD31C4D8F572A3D8CDA405E5EE86B62',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '700-721 S Pace Bend Rd',
#   'issue_reported': 'COLLISION WITH INJURY',
#   'latitude': '30.4074919',
#   'location': '(30.4074919,-98.0587584)',
#   'longitude': '-98.0587584',
#   'published_date': '2017-10-03T08:32:00.000',
#   'traffic_report_id': 'D1D904BDB4FAEC931ACB49890B51B0657C0BB751',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2430-2432 W Ben White Blvd Wb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.2323885',
#   'location': '(30.2323885,-97.802227)',
#   'longitude': '-97.802227',
#   'published_date': '2017-10-03T08:35:00.000',
#   'traffic_report_id': 'E6E50CC4CC91E09DEDDF941F21B397FCE5ED58BD',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'San Jacinto Blvd & E 10th St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2711181',
#   'location': '(30.2711181,-97.7390029)',
#   'longitude': '-97.7390029',
#   'published_date': '2017-10-03T08:46:00.000',
#   'traffic_report_id': 'A02A2FE9596BF1F59BD4CA2ECA3885C814393F10',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '8200-blk W Us 290 Hwy',
#   'issue_reported': 'COLLISION',
#   'published_date': '2017-10-03T08:48:00.000',
#   'traffic_report_id': 'C84C7C86AC0619B3CD69A0F9D185EB5D6030D751',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '300-325 E Ben White Blvd Eb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2247884',
#   'location': '(30.2247884,-97.7664085)',
#   'longitude': '-97.7664085',
#   'published_date': '2017-10-03T08:58:00.000',
#   'traffic_report_id': 'D9B6765DFC562D6CED8A8AA9CFCF1ACDA82DCAA3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '10200-10225 Anderson Mill Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4472168',
#   'location': '(30.4472168,-97.8022882)',
#   'longitude': '-97.8022882',
#   'published_date': '2017-10-03T09:04:00.000',
#   'traffic_report_id': '3CFC55B34E891B01039A034BD40231D1AF0C4114',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3501 Mount Bonnell Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3170034',
#   'location': '(30.3170034,-97.7741796)',
#   'longitude': '-97.7741796',
#   'published_date': '2017-10-03T09:05:00.000',
#   'traffic_report_id': '134B8816608BA8D017CB8BD37A8C8491B0AAB268',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '7901 N Ih 35 Svrd Nb',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.3407675',
#   'location': '(30.3407675,-97.6985749)',
#   'longitude': '-97.6985749',
#   'published_date': '2017-10-03T09:10:00.000',
#   'traffic_report_id': 'DD01903921EA24941C26A48F2CEC24E0BB0E8CC7',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '100-124 W 8th St',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2699737',
#   'location': '(30.2699737,-97.7421413)',
#   'longitude': '-97.7421413',
#   'published_date': '2017-10-03T09:13:00.000',
#   'traffic_report_id': '9F6BF828C80134B8D3E07B058045FBA6ACD4E9AC',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5509-5516 Mount Bonnell Rd',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3392968',
#   'location': '(30.3392968,-97.7779863)',
#   'longitude': '-97.7779863',
#   'published_date': '2017-10-03T09:16:00.000',
#   'traffic_report_id': '1966E694BAD90686516F99CDF432800FDCA39290',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Woodrow Ave & Houston St',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.326388',
#   'location': '(30.326388,-97.7344668)',
#   'longitude': '-97.7344668',
#   'published_date': '2017-10-03T09:29:00.000',
#   'traffic_report_id': '290448489A06C6A2DC62E82491212444BD6E341F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Grove Blvd & E Riverside Dr',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2270301',
#   'location': '(30.2270301,-97.7079338)',
#   'longitude': '-97.7079338',
#   'published_date': '2017-10-03T09:32:00.000',
#   'traffic_report_id': 'DFF17A997C0881052E744E1A816ECDE7332018A3',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2501-3135 Scofield Ridge Pkwy',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.429313',
#   'location': '(30.429313,-97.6954089)',
#   'longitude': '-97.6954089',
#   'published_date': '2017-10-03T09:42:00.000',
#   'traffic_report_id': '6C8E459F96D9CF05E1FAC5432DF1066B42609E52',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'N Lamar Blvd & W Rundberg Ln',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3631457',
#   'location': '(30.3631457,-97.6970285)',
#   'longitude': '-97.6970285',
#   'published_date': '2017-10-03T09:47:00.000',
#   'traffic_report_id': '415D2E4353963C539961C46AD289844F4093BA96',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '5801 N Ih 35 Svrd Nb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3184108',
#   'location': '(30.3184108,-97.7068192)',
#   'longitude': '-97.7068192',
#   'published_date': '2017-10-03T09:54:00.000',
#   'traffic_report_id': '6B4142E2E97B851A319B0FCAB23709B40E3FC19F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'S Lamar Blvd & Barton Springs Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2608678',
#   'location': '(30.2608678,-97.7585333)',
#   'longitude': '-97.7585333',
#   'published_date': '2017-10-03T09:57:00.000',
#   'traffic_report_id': '8D25B4C973C5DAFA021036664B080A79E0BB69A0',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13631-13815 N Sh 45 W Eb',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4737071',
#   'location': '(30.4737071,-97.7792374)',
#   'longitude': '-97.7792374',
#   'published_date': '2017-10-03T09:59:00.000',
#   'traffic_report_id': '05FA2DE99C48086B28D6E7A491A75F6F313AF79D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '0 MOPAC SB TO RESEARCH SB RAMP',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3817518',
#   'location': '(30.3817518,-97.7373934)',
#   'longitude': '-97.7373934',
#   'published_date': '2017-10-03T10:00:00.000',
#   'traffic_report_id': '662791B56C06D86D3C0CB16E8163662DD014FD9F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '14901 - 15237 N MOPAC EXPY SVRD NB',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.45496',
#   'location': '(30.45496,-97.6964897)',
#   'longitude': '-97.6964897',
#   'published_date': '2017-10-03T10:02:00.000',
#   'traffic_report_id': 'EC99F53E14FDFE8DBD7FFC6455A4B4CF46E5C609',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '600-1625 S Sh 130 Nb',
#   'issue_reported': 'COLLISION WITH INJURY',
#   'latitude': '30.2368152',
#   'location': '(30.2368152,-97.6172488)',
#   'longitude': '-97.6172488',
#   'published_date': '2017-10-03T10:07:00.000',
#   'traffic_report_id': '0E51425BC6723D418B7C9E1894575DB504FFBAD8',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '3800 Mount Bonnell Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3209038',
#   'location': '(30.3209038,-97.7728708)',
#   'longitude': '-97.7728708',
#   'published_date': '2017-10-03T10:12:00.000',
#   'traffic_report_id': '9D9859EF101E69D0B68952447676060A3591DC47',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9800-10016 N Lamar Blvd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3674741',
#   'location': '(30.3674741,-97.6946041)',
#   'longitude': '-97.6946041',
#   'published_date': '2017-10-03T10:13:00.000',
#   'traffic_report_id': '9AE17B153A32567D1646CAA8C4010174C30AC349',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '1511 Cripple Creek Dr',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.378059',
#   'location': '(30.378059,-97.7040813)',
#   'longitude': '-97.7040813',
#   'published_date': '2017-10-03T10:19:00.000',
#   'traffic_report_id': 'FEE8346A5A401A9C314846811346613D2DDF998C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '2814-2922 W Anderson Ln',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.3591259',
#   'location': '(30.3591259,-97.7369454)',
#   'longitude': '-97.7369454',
#   'published_date': '2017-10-03T10:27:00.000',
#   'traffic_report_id': '259FE583DDD64DF1EFA6B2CBF7A1AFAE427CFA5D',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '6900 N Fm 620 Rd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.4023614',
#   'location': '(30.4023614,-97.8548259)',
#   'longitude': '-97.8548259',
#   'published_date': '2017-10-03T10:31:00.000',
#   'traffic_report_id': '00FD4B4549A1094AAE926EF62E9DBD3CDCC2E456',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '600 Barwood Park',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.349174',
#   'location': '(30.349174,-97.6963662)',
#   'longitude': '-97.6963662',
#   'published_date': '2017-10-03T10:33:00.000',
#   'traffic_report_id': 'FF33A8F10515011CBA0D191AE58F7F9A4DD7A3E1',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Barton Springs Rd & S Lamar Blvd',
#   'issue_reported': 'Traffic Impediment',
#   'latitude': '30.2608678',
#   'location': '(30.2608678,-97.7585333)',
#   'longitude': '-97.7585333',
#   'published_date': '2017-10-03T10:37:00.000',
#   'traffic_report_id': '54164C3DB2C5171B138C809D3CBE7A6637C31CBF',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Woodrow Ave & Houston St',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.326388',
#   'location': '(30.326388,-97.7344668)',
#   'longitude': '-97.7344668',
#   'published_date': '2017-10-03T10:58:00.000',
#   'traffic_report_id': '93E35532E8C27DA7267D6A073DA0D909DA11A4ED',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '13435 N Us 183 Hwy Svrd Nb',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.4476471',
#   'location': '(30.4476471,-97.7895542)',
#   'longitude': '-97.7895542',
#   'published_date': '2017-10-03T11:01:00.000',
#   'traffic_report_id': '9BD7909EA32C89F68E82ED0CBE1F30A2E1D72B1C',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Red Wagon Ln & Trails End Rd',
#   'issue_reported': 'LOOSE LIVESTOCK',
#   'latitude': '30.4944221',
#   'location': '(30.4944221,-97.8916115)',
#   'longitude': '-97.8916115',
#   'published_date': '2017-10-03T11:02:00.000',
#   'traffic_report_id': 'A7D42994083C2352E0EEC3EC00AA9B3B3DB00CA6',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '11607 N Lamar Blvd',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.3858831',
#   'location': '(30.3858831,-97.6842789)',
#   'longitude': '-97.6842789',
#   'published_date': '2017-10-03T11:05:00.000',
#   'traffic_report_id': '4080612570BE15E797C5DAE4449E556F77FAA2FA',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'W Us 290 Hwy & W William Cannon Dr',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2340612',
#   'location': '(30.2340612,-97.8648376)',
#   'longitude': '-97.8648376',
#   'published_date': '2017-10-03T11:08:00.000',
#   'traffic_report_id': 'F8997252C6E5AE3D950B736E1A81160A2E937A7F',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Maybelle Ave & W 45th St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.314905',
#   'location': '(30.314905,-97.7405678)',
#   'longitude': '-97.7405678',
#   'published_date': '2017-10-03T11:08:00.000',
#   'traffic_report_id': '1C90B882D4AC9C7D95D597BD8B37E3BFA36AEC00',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '803 E Riverside Dr',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2505462',
#   'location': '(30.2505462,-97.7404218)',
#   'longitude': '-97.7404218',
#   'published_date': '2017-10-03T11:13:00.000',
#   'traffic_report_id': '4F2B344C5268B61FB41F14C640AEAF89BB7AE6D7',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Alta Vista Ave & E Riverside Dr',
#   'issue_reported': 'Crash Urgent',
#   'latitude': '30.2501242',
#   'location': '(30.2501242,-97.7396736)',
#   'longitude': '-97.7396736',
#   'published_date': '2017-10-03T11:14:00.000',
#   'traffic_report_id': '02EF6A4D5E9B6440EE4513BAF40746CB8E872FE4',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': 'Chalmers Ave & Willow St',
#   'issue_reported': 'Crash Service',
#   'latitude': '30.2569209',
#   'location': '(30.2569209,-97.7270816)',
#   'longitude': '-97.7270816',
#   'published_date': '2017-10-03T11:30:00.000',
#   'traffic_report_id': '09CAD82F43C6FCF04357B175CDF4763A3DAF9A89',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  {'address': '9161-9239 Research Blvd Svrd Nb',
#   'issue_reported': 'Traffic Hazard',
#   'latitude': '30.3763045',
#   'location': '(30.3763045,-97.7316178)',
#   'longitude': '-97.7316178',
#   'published_date': '2017-10-03T11:31:00.000',
#   'traffic_report_id': 'E816958259E39339DDC56994E959AA56EF874F92',
#   'traffic_report_status': 'ARCHIVED',
#   'traffic_report_status_date_time': '2018-05-17T20:00:00.000'},
#  ...]

# %%
# Converts the Data into a DataFrame
df = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

# Save data as csv
df.to_csv('./traffic.csv')

df.head()
# Out:
#                           address issue_reported    latitude  \
# 0                  5400 Brodie Ln      COLLISION  30.2303264
# 1            8800 Corran Ferry Dr  Crash Service  30.2016097
# 2     N Lamar Blvd Nb & Morrow St   Crash Urgent  30.3439776
# 3                11000 Fm 2222 Rd  Crash Service  30.3966315
# 4  Mount Bonnell Rd & Tortuga Trl  Crash Service   30.339233
#
#                    location    longitude           published_date  \
# 0  (30.2303264,-97.8199774)  -97.8199774  2017-09-26T11:11:00.000
# 1  (30.2016097,-97.8530411)  -97.8530411  2017-09-26T11:19:00.000
# 2  (30.3439776,-97.7149716)  -97.7149716  2017-09-26T11:55:00.000
# 3  (30.3966315,-97.8487281)  -97.8487281  2017-09-26T12:08:00.000
# 4   (30.339233,-97.7779837)  -97.7779837  2017-09-26T12:20:00.000
#
#                           traffic_report_id traffic_report_status  \
# 0  EC10DB9185C9C58A004FA683DD21AFCD16CAD418              ARCHIVED
# 1  B25B748A59D8B6B5B5AE3E9D985289E795C874ED              ARCHIVED
# 2  B17F4787F2799F2665E5F119FC2F47D569212C4C              ARCHIVED
# 3  15D1EE116284B85E5DE3E00564518367FE994DE7              ARCHIVED
# 4  89CA91E6C9B28BDCFB629B12758F955D21072594              ARCHIVED
#
#   traffic_report_status_date_time
# 0         2018-05-17T20:00:00.000
# 1         2018-05-17T20:00:00.000
# 2         2018-05-17T20:00:00.000
# 3         2018-05-17T20:00:00.000
# 4         2018-05-17T20:00:00.000

# %%
# See if there is any missing values on the data acquired
df.count()
# Out:
# address                            82033
# issue_reported                     82033
# latitude                           81954
# location                           81794
# longitude                          81954
# published_date                     82033
# traffic_report_id                  82033
# traffic_report_status              80340
# traffic_report_status_date_time    82033
# dtype: int64

# %%
# Drop incomplete values
df=df.dropna()
df.count()
# Out:
# address                            80107
# issue_reported                     80107
# latitude                           80107
# location                           80107
# longitude                          80107
# published_date                     80107
# traffic_report_id                  80107
# traffic_report_status              80107
# traffic_report_status_date_time    80107
# dtype: int64

# %%
# Find the diferent categories for "issue reported"
df['issue_reported'].value_counts()
# Out:
# Traffic Hazard                23826
# Crash Urgent                  18029
# Crash Service                 13246
# Traffic Impediment             6101
# COLLISION                      5404
# TRFC HAZD/ DEBRIS              4629
# zSTALLED VEHICLE               3426
# COLLISION WITH INJURY          2023
# LOOSE LIVESTOCK                1624
# COLLISN/ LVNG SCN              1150
# COLLISION/PRIVATE PROPERTY      272
# VEHICLE FIRE                    180
# BLOCKED DRIV/ HWY               111
# ICY ROADWAY                      24
# BOAT ACCIDENT                    22
# AUTO/ PED                        14
# FLEET ACC/ INJURY                12
# TRAFFIC FATALITY                 11
# N / HZRD TRFC VIOL                1
# HIGH WATER                        1
# COLLISN / FTSRA                   1
# Name: issue_reported, dtype: int64

# %%
# –––––––––––––––––––––––––– * RENAMING CATEGORIES * ––––––––––––––––––––––––––  #
# Clean up issue_reported category. Replace 'Accident/Collision' in a single category.

#ACCIDENT COLLISION
df['issue_reported'] = df['issue_reported'].replace({
    'Crash Urgent': 'Accident/Collision', 'Crash Service': 'Accident/Collision',
    'COLLISION': 'Accident/Collision', 'COLLISION WITH INJURY': 'Accident/Collision',
    'COLLISN/ LVNG SCN': 'Accident/Collision', 'COLLISN / FTSRA': 'Accident/Collision',
    'COLLISION/PRIVATE PROPERTY': 'Accident/Collision', 'COLLISN/ LVNG SCN': 'Accident/Collision',
    'AUTO/ PED': 'Accident/Collision','FLEET ACC/ INJURY': 'Accident/Collision',
    'TRAFFIC FATALITY': 'Accident/Collision'})

#TRAFFIC IMPEDIMENT
df['issue_reported'] = df['issue_reported'].replace({
    'zSTALLED VEHICLE': 'Traffic Impediment', 'BLOCKED DRIV/ HWY': 'Traffic Impediment',
    'LOOSE LIVESTOCK': 'Traffic Impediment'})


#TRAFFIC HAZARD
df['issue_reported'] = df['issue_reported'].replace({
    'TRFC HAZD/ DEBRIS': 'Traffic Hazard', 'N / HZRD TRFC VIOL': 'Traffic Hazard',
    'ICY ROADWAY': 'Traffic Hazard', 'HIGH WATER': 'Traffic Hazard',
    'VEHICLE FIRE': 'Traffic Hazard', 'HIGH WATER': 'Traffic Hazard'})

# Drop the values for 'BOAT ACCIDENT' since those are not of interest for the study.
df = df[df.issue_reported != 'BOAT ACCIDENT']

df['issue_reported'].value_counts()
# Out:
# Accident/Collision    40162
# Traffic Hazard        28661
# Traffic Impediment    11262
# Name: issue_reported, dtype: int64
